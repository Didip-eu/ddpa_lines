# %% [markdown]
# # Charters with Chrismon

# %%
import re
import pandas as pd

df = pd.read_json("../../data/output/charters_full_2022-11-22-1044.json")
df[df["cei_tenor_joined"].astype(str).str.contains('^\+', regex=True)]
# Out:
#                                                   atom_id  \
# 1       [tag:www.monasterium.net,2011:/charter/069622f...
# 36552   [tag:www.monasterium.net,2011:/charter/AT-HHSt...
# 36578   [tag:www.monasterium.net,2011:/charter/AT-HHSt...
# 36579   [tag:www.monasterium.net,2011:/charter/AT-HHSt...
# 36602   [tag:www.monasterium.net,2011:/charter/AT-HHSt...
# ...                                                   ...
# 187034  [tag:www.monasterium.net,2011:/charter/CSGX/13...
# 189405  [tag:www.monasterium.net,2011:/charter/CZ-KAVB...
# 216764  [tag:www.monasterium.net,2011:/charter/da7833d...
# 615454  [tag:www.monasterium.net,2011:/charter/PassauS...
# 658217  [tag:www.monasterium.net,2011:/charter/Westfal...
#
#                                       cei_abstract_joined  \
# 1       Palermo de Caserta, figlio dei defunti Giovann...
# 36552   Papst Johann XII. bestätigt der Salzburger Kir...
# 36578   Eb Konrad I. beurkundet die Beilegung seines S...
# ...
