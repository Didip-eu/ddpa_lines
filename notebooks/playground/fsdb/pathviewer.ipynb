# %%
import pandas as pd
import json

# %%
with open("../../../data/tmp/data/leech_db/chatomid_db_paths.json", "r") as f:
    data = json.load(f)

# %%
data
# Out:
# {'data/db/mom-data/metadata.charter.public/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0632d68f-f907-4113-886d-d7afd25339ef.cei.xml': 'tag:www.monasterium.net,2011:/charter/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0632d68f-f907-4113-886d-d7afd25339ef',
#  'data/db/mom-data/metadata.charter.public/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0e3d1203-0e72-4b17-834e-35e93efed610.cei.xml': 'tag:www.monasterium.net,2011:/charter/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0e3d1203-0e72-4b17-834e-35e93efed610',
#  'data/db/mom-data/metadata.charter.public/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0eb5100f-8132-48fd-a0d9-6704f70b4d50.cei.xml': 'tag:www.monasterium.net,2011:/charter/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/0eb5100f-8132-48fd-a0d9-6704f70b4d50',
#  'data/db/mom-data/metadata.charter.public/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/16bfa2f5-9171-4d18-b9c7-1f755234ef65.cei.xml': 'tag:www.monasterium.net,2011:/charter/069622fc-5d55-4a51-8dd5-f23f30d8bf2f/16bfa2f5-9171-4d18-b9c7-1f755234ef65',
# ...

# %%
newdf = pd.DataFrame.from_dict(data, orient='index').reset_index

# %%
newdf.columns.values[0] = "path"
newdf.columns.values[1] = "atomid"

# %%
sample = newdf.sample(n=10)

# %%
newlist = sample.iloc[:, 1].to_list()

# %%
newlist
# Out:
# ['tag:www.monasterium.net,2011:/charter/IT-ASFi/DNPistoiaComune/00032355',
#  'tag:www.monasterium.net,2011:/charter/IT-ASFi/DNCamaldoli/00015747',
#  'tag:www.monasterium.net,2011:/charter/IT-BSNSP/08-S_Maria_della_Grotta/3_BB_II_37',
#  'tag:www.monasterium.net,2011:/charter/OOEUB/1359_XI_25.1',
#  'tag:www.monasterium.net,2011:/charter/HU-MNL-DLCSLP/ESTCSQ67/32645',
#  'tag:www.monasterium.net,2011:/charter/AT-StiASch/SchlierbachOCist/1598_VII_15',
#  'tag:www.monasterium.net,2011:/charter/HU-MNL-DLKINL/MKANRAQ311/45080',
#  'tag:www.monasterium.net,2011:/charter/DE-HLBFulda/urkunden/149',
#  'tag:www.monasterium.net,2011:/charter/IT-ASFi/DNRiformagioniAttiPubblici/00055927',
#  'tag:www.monasterium.net,2011:/charter/AbteiSanctGallen/dbf6feba-c677-4a7f-a9b2-e6b51f54ebdc']

# %%
filtered_dict = {k: v for k, v in data.items() if v in newlist}
filtered_dict
# Out:
# {'data/db/mom-data/metadata.charter.public/AbteiSanctGallen/dbf6feba-c677-4a7f-a9b2-e6b51f54ebdc.cei.xml': 'tag:www.monasterium.net,2011:/charter/AbteiSanctGallen/dbf6feba-c677-4a7f-a9b2-e6b51f54ebdc',
#  'data/db/mom-data/metadata.charter.public/AT-StiASch/SchlierbachOCist/1598_VII_15.cei.xml': 'tag:www.monasterium.net,2011:/charter/AT-StiASch/SchlierbachOCist/1598_VII_15',
#  'data/db/mom-data/metadata.charter.public/DE-HLBFulda/urkunden/149.cei.xml': 'tag:www.monasterium.net,2011:/charter/DE-HLBFulda/urkunden/149',
#  'data/db/mom-data/metadata.charter.public/HU-MNL-DLCSLP/ESTCSQ67/32645.cei.xml': 'tag:www.monasterium.net,2011:/charter/HU-MNL-DLCSLP/ESTCSQ67/32645',
#  'data/db/mom-data/metadata.charter.public/HU-MNL-DLKINL/MKANRAQ311/45080.cei.xml': 'tag:www.monasterium.net,2011:/charter/HU-MNL-DLKINL/MKANRAQ311/45080',
#  'data/db/mom-data/metadata.charter.public/IT-ASFi/DNCamaldoli/00015747.cei.xml': 'tag:www.monasterium.net,2011:/charter/IT-ASFi/DNCamaldoli/00015747',
# ...
